# %%
# 1.Create two variables: one integer with value 25 and one float with value 3.5. Print both    variables.
a = 25
b = 3.5
print(a , b)
# Out:
# 25 3.5

# %%
# 2. Create a string variable with your name and a boolean variable with value True. Print both values.
name = "Talha"
bol = True
print(name , bol)
# Out:
# Talha True

# %%
# 3.Write a program that takes two numbers from the user and prints their addition, subtraction, multiplication, and division.
Num1 = int(input("Enter 1st Number: "))
Num2 = int(input("Enter 2nd Number: "))
print("The Sum is:", Num1+Num2)
print("The Subtraction is:" , Num1-Num2)
print("The Multiplication is:", Num1*Num2)
print("The Division is:",Num1/Num2)
# Out:
# Enter 1st Number: 3
# Enter 2nd Number: 5
# The Sum is: 8
# The Subtraction is: -2
# The Multiplication is: 15
# The Division is: 0.6

# %%
# 4.Write a program that takes a number from the user and prints the result of floor division by 5 and the remainder when divided by 5.
Num = int(input("Enter a Number :  "))
print("The Floor Divisin is:" , Num//5 )
print("The Remainder Divisin is:" , Num%5 )
# Out:
# Enter a Number :  4
# The Floor Divisin is: 0
# The Remainder Divisin is: 4

# %%
# 5. Write one example of an expression and one example of a statement in Python.
Expression = 100+289-(187/2*3)
Statement = print("Hello World")
# Out:
# Hello World

# %%
# 6.Take a number as input from the user, convert it to an integer, multiply it by 10, and print the result.
a = input("Enter a Number: ")
b = int(a) * 10
print(b)
# Out:
# Enter a Number: 6
# 60

# %%
# 7.Create two string variables (first name and last name), join them using the + operator, and print the full name.
firstName = "Talha"
lastName = "Mueen"
fullName = firstName +" "+lastName
print(fullName)
# Out:
# Talha Mueen

# %%
# 8. Take a word from the user and print it three times using the * operator.
word = input("Enter a Word: ")
print(word*3)
# Out:
# Enter a Word: hi
# hihihi

# %%
# 9.Given a string "Python Programming", print the first 6 characters and the remaining characters using slicing.
str =  "Python Programming"
print(str[0:6])
print(str[6:])
# Out:
# Python
#  Programming

# %%
# 10.Given a string "hello world", print it in uppercase, in title case, and print its length.
str =  "hello world"
print(str.upper())
print(str.title())
print(len(str))
# Out:
# HELLO WORLD
# Hello World
# 11
